# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Example: If you uploaded my_dataset.zip directly to /content/
ZIP_FILE = "/content/drive/MyDrive/MindScan/binary_dataset.zip"

# Destination folder where the extracted files will go (e.g., /content/data/)
DEST_FOLDER = "/content/MindScan/"

# Create the destination folder first
# !mkdir -p {DEST_FOLDER}

# Use the unzip command
# -q makes it quiet (no long output list), -d sets the destination directory
# !unzip -q {ZIP_FILE} -d {DEST_FOLDER}

print(f"Extraction complete. Data is ready in: {DEST_FOLDER}")
# Out:
# Extraction complete. Data is ready in: /content/MindScan/

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import models, transforms
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from tqdm import trange, tqdm

# ===========================
# 1️⃣ CONFIGURATION
# ===========================
DATA_ROOT = "/content/MindScan/binary_dataset"  # Path to normalized data
TRAIN_DIR = os.path.join(DATA_ROOT, "Training")
TEST_DIR  = os.path.join(DATA_ROOT, "Testing")

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 32
IMG_SIZE = 224
EPOCHS = 20
LR = 1e-4
WEIGHT_DECAY = 1e-4
PATIENCE = 3  # Early stopping patience
BEST_MODEL_PATH = "resnet18_binary_tumor.pth"

# ===========================
# 2️⃣ CUSTOM DATASET
# ===========================
class NpyDataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data, self.labels = [], []
        self.transform = transform
        self.classes = sorted(os.listdir(data_dir))
        self.class_to_idx = {cls_name: i for i, cls_name in enumerate(self.classes)}

        for cls_name in self.classes:
            cls_dir = os.path.join(data_dir, cls_name)
            if not os.path.isdir(cls_dir):
                continue
            for f in os.listdir(cls_dir):
                if f.endswith('.npy'):
                    self.data.append(os.path.join(cls_dir, f))
                    self.labels.append(self.class_to_idx[cls_name])

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        x = np.load(self.data[idx])
        x = torch.tensor(x, dtype=torch.float32)

        # Ensure 3-channel (C, H, W)
        if x.ndim == 2:  # (H, W)
            x = x.unsqueeze(0).repeat(3, 1, 1)
        elif x.ndim == 3:
            if x.shape[0] == 1:
                x = x.repeat(3, 1, 1)
            elif x.shape[0] == 2:
                x = torch.cat([x[0:1], x], dim=0)
            elif x.shape[0] > 3:
                x = x[:3, :, :]
            # assume already (C,H,W) if x.shape[0]==3

        # Apply transform
        if self.transform:
            x = self.transform(x)

        y = torch.tensor(self.labels[idx], dtype=torch.long)
        return x, y

# ===========================
# 3️⃣ TRANSFORMS
# ===========================
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# ===========================
# 4️⃣ LOAD DATA
# ===========================
train_dataset = NpyDataset(TRAIN_DIR, transform=transform)
test_dataset  = NpyDataset(TEST_DIR, transform=transform)

print("Train class counts:", Counter(train_dataset.labels))
print("Test class counts:", Counter(test_dataset.labels))

# Optional: balance training dataset
def balance_dataset(dataset):
    counts = Counter(dataset.labels)
    min_count = min(counts.values())
    idxs = []
    for label in counts.keys():
        label_idxs = [i for i, y in enumerate(dataset.labels) if y == label]
        idxs.extend(np.random.choice(label_idxs, min_count, replace=False))
    return Subset(dataset, idxs)

balanced_train = balance_dataset(train_dataset)

train_loader = DataLoader(balanced_train, batch_size=BATCH_SIZE, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# ===========================
# 5️⃣ MODEL DEFINITION
# ===========================
model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)

# Freeze early layers
for param in model.layer1.parameters():
    param.requires_grad = False
for param in model.layer2.parameters():
    param.requires_grad = False

num_ftrs = model.fc.in_features
model.fc = nn.Sequential(
    nn.Dropout(0.5),
    nn.Linear(num_ftrs, 2)  # Binary classification
)

model = model.to(DEVICE)

# ===========================
# 6️⃣ LOSS AND OPTIMIZER
# ===========================
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

# ===========================
# 7️⃣ TRAINING LOOP WITH EARLY STOPPING
# ===========================
best_val_loss = float("inf")
wait = 0

for epoch in trange(1, 1 + EPOCHS, desc="Training Epochs"):
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # tqdm for batches
    for images, labels in tqdm(train_loader, desc=f"Epoch {epoch} batches", leave=False):
        images, labels = images.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    train_loss = running_loss / len(train_loader)   # ✅ define train_loss
    train_acc = 100 * correct / total
    print(f"Epoch {epoch} | Train Loss: {train_loss:.4f}, Acc: {train_acc:.2f}%")

    # Validation
    model.eval()
    val_loss, val_correct, val_total = 0, 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * images.size(0)
            _, preds = outputs.max(1)
            val_correct += preds.eq(labels).sum().item()
            val_total += labels.size(0)

    val_loss /= len(test_loader.dataset)
    val_acc = 100 * val_correct / val_total

    print(f"Epoch [{epoch}/{EPOCHS}] | "
          f"Train Loss: {train_loss:.4f}, Acc: {train_acc:.2f}% | "
          f"Val Loss: {val_loss:.4f}, Acc: {val_acc:.2f}%")

    # Early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        wait = 0
        torch.save(model.state_dict(), BEST_MODEL_PATH)
    else:
        wait += 1
        if wait >= PATIENCE:
            print(f"Early stopping at epoch {epoch}")
            break

print(f"✅ Best model saved to {BEST_MODEL_PATH}")

# ===========================
# 8️⃣ EVALUATION
# ===========================
model.load_state_dict(torch.load(BEST_MODEL_PATH))
model.eval()

all_preds, all_labels = [], []
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(DEVICE), labels.to(DEVICE)
        outputs = model(images)
        _, preds = outputs.max(1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

print("\nClassification Report:")
print(classification_report(all_labels, all_preds, target_names=train_dataset.classes))

# Confusion matrix
cm = confusion_matrix(all_labels, all_preds)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=train_dataset.classes,
            yticklabels=train_dataset.classes)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Train class counts: Counter({1: 4117, 0: 1595})
# Test class counts: Counter({1: 906, 0: 405})
# Training Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 1 batches:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1 batches:   1%|          | 1/100 [00:00<00:18,  5.50it/s]
# Epoch 1 batches:   2%|▏         | 2/100 [00:00<00:17,  5.50it/s]
# Epoch 1 batches:   3%|▎         | 3/100 [00:00<00:16,  5.72it/s]
# Epoch 1 batches:   4%|▍         | 4/100 [00:00<00:16,  5.95it/s]
# Epoch 1 batches:   5%|▌         | 5/100 [00:00<00:15,  6.07it/s]
# Epoch 1 batches:   6%|▌         | 6/100 [00:01<00:15,  6.04it/s]
# Epoch 1 batches:   7%|▋         | 7/100 [00:01<00:14,  6.22it/s]
# Epoch 1 batches:   8%|▊         | 8/100 [00:01<00:14,  6.30it/s]
# Epoch 1 batches:   9%|▉         | 9/100 [00:01<00:14,  6.39it/s]
# Epoch 1 batches:  10%|█         | 10/100 [00:01<00:13,  6.47it/s]
# Epoch 1 batches:  11%|█         | 11/100 [00:01<00:13,  6.50it/s]
# Epoch 1 batches:  12%|█▏        | 12/100 [00:01<00:13,  6.35it/s]
# Epoch 1 batches:  13%|█▎        | 13/100 [00:02<00:13,  6.43it/s]
# Epoch 1 batches:  86%|████████▌ | 86/100 [00:16<00:03,  4.29it/s]
# Epoch 1 batches:  87%|████████▋ | 87/100 [00:16<00:03,  4.14it/s]
# Epoch 1 batches:  88%|████████▊ | 88/100 [00:16<00:03,  3.87it/s]
# Epoch 1 batches:  89%|████████▉ | 89/100 [00:17<00:02,  4.00it/s]
# Epoch 1 batches:  90%|█████████ | 90/100 [00:17<00:02,  3.66it/s]
# Epoch 1 batches:  91%|█████████ | 91/100 [00:17<00:02,  3.64it/s]
# Epoch 1 batches:  92%|█████████▏| 92/100 [00:18<00:02,  3.72it/s]
# Epoch 1 batches:  93%|█████████▎| 93/100 [00:18<00:01,  3.51it/s]
# Epoch 1 batches:  94%|█████████▍| 94/100 [00:18<00:01,  3.52it/s]
# Epoch 1 batches:  95%|█████████▌| 95/100 [00:18<00:01,  3.73it/s]
# Epoch 1 batches:  96%|█████████▌| 96/100 [00:19<00:01,  3.38it/s]
# Epoch 1 batches:  97%|█████████▋| 97/100 [00:19<00:00,  3.35it/s]
# Epoch 1 batches:  98%|█████████▊| 98/100 [00:19<00:00,  3.60it/s]
# Epoch 1 batches:  99%|█████████▉| 99/100 [00:20<00:00,  3.68it/s]
# Epoch 1 batches: 100%|██████████| 100/100 [00:20<00:00,  4.04it/s]
# Epoch 1 | Train Loss: 0.0895, Acc: 96.90%
# Training Epochs:   5%|▌         | 1/20 [00:25<08:00, 25.32s/it]
# Epoch [1/20] | Train Loss: 0.0895, Acc: 96.90% | Val Loss: 0.0776, Acc: 97.03%
# Epoch 2 batches:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 2 batches:   1%|          | 1/100 [00:00<00:21,  4.69it/s]
# Epoch 2 batches:   2%|▏         | 2/100 [00:00<00:21,  4.65it/s]
# Epoch 2 batches:   3%|▎         | 3/100 [00:00<00:18,  5.20it/s]
# Epoch 2 batches:   4%|▍         | 4/100 [00:00<00:17,  5.45it/s]
# Epoch 2 batches:   5%|▌         | 5/100 [00:00<00:16,  5.63it/s]
# Epoch 2 batches:   6%|▌         | 6/100 [00:01<00:15,  5.89it/s]
# Epoch 2 batches:   7%|▋         | 7/100 [00:01<00:15,  6.06it/s]
# Epoch 2 batches:   8%|▊         | 8/100 [00:01<00:14,  6.18it/s]
# Epoch 2 batches:   9%|▉         | 9/100 [00:01<00:14,  6.13it/s]
# Epoch 2 batches:  10%|█         | 10/100 [00:01<00:14,  6.29it/s]
# Epoch 2 batches:  11%|█         | 11/100 [00:01<00:13,  6.39it/s]
# Epoch 2 batches:  12%|█▏        | 12/100 [00:02<00:13,  6.43it/s]
# Epoch 2 batches:  13%|█▎        | 13/100 [00:02<00:13,  6.45it/s]
# Epoch 2 batches:  14%|█▍        | 14/100 [00:02<00:13,  6.47it/s]
# Epoch 2 batches:  15%|█▌        | 15/100 [00:02<00:13,  6.41it/s]
# Epoch 2 batches:  16%|█▌        | 16/100 [00:02<00:12,  6.48it/s]
# Epoch 2 batches:  17%|█▋        | 17/100 [00:02<00:12,  6.53it/s]
# Epoch 2 batches:  18%|█▊        | 18/100 [00:02<00:12,  6.49it/s]
# Epoch 2 batches:  90%|█████████ | 90/100 [00:14<00:01,  6.37it/s]
# Epoch 2 batches:  91%|█████████ | 91/100 [00:14<00:01,  6.43it/s]
# Epoch 2 batches:  92%|█████████▏| 92/100 [00:14<00:01,  6.46it/s]
# Epoch 2 batches:  93%|█████████▎| 93/100 [00:15<00:01,  6.48it/s]
# Epoch 2 batches:  94%|█████████▍| 94/100 [00:15<00:00,  6.50it/s]
# Epoch 2 batches:  95%|█████████▌| 95/100 [00:15<00:00,  6.49it/s]
# Epoch 2 batches:  96%|█████████▌| 96/100 [00:15<00:00,  6.37it/s]
# Epoch 2 batches:  97%|█████████▋| 97/100 [00:15<00:00,  6.35it/s]
# Epoch 2 batches:  98%|█████████▊| 98/100 [00:15<00:00,  6.39it/s]
# Epoch 2 batches:  99%|█████████▉| 99/100 [00:16<00:00,  6.29it/s]
# Epoch 2 batches: 100%|██████████| 100/100 [00:16<00:00,  6.89it/s]
# Epoch 2 | Train Loss: 0.0088, Acc: 99.75%
# Training Epochs:  10%|█         | 2/20 [00:45<06:42, 22.35s/it]
# Epoch [2/20] | Train Loss: 0.0088, Acc: 99.75% | Val Loss: 0.0974, Acc: 97.18%
# Epoch 3 batches:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 3 batches:   1%|          | 1/100 [00:00<00:16,  6.09it/s]
# Epoch 3 batches:   2%|▏         | 2/100 [00:00<00:15,  6.25it/s]
# Epoch 3 batches:   3%|▎         | 3/100 [00:00<00:15,  6.31it/s]
# Epoch 3 batches:   4%|▍         | 4/100 [00:00<00:15,  6.17it/s]
# Epoch 3 batches:   5%|▌         | 5/100 [00:00<00:15,  6.20it/s]
# Epoch 3 batches:   6%|▌         | 6/100 [00:00<00:15,  6.20it/s]
# Epoch 3 batches:   7%|▋         | 7/100 [00:01<00:14,  6.32it/s]
# Epoch 3 batches:   8%|▊         | 8/100 [00:01<00:14,  6.39it/s]
# Epoch 3 batches:   9%|▉         | 9/100 [00:01<00:14,  6.27it/s]
# Epoch 3 batches:  10%|█         | 10/100 [00:01<00:14,  6.37it/s]
# Epoch 3 batches:  11%|█         | 11/100 [00:01<00:13,  6.41it/s]
# Epoch 3 batches:  12%|█▏        | 12/100 [00:01<00:13,  6.39it/s]
# Epoch 3 batches:  13%|█▎        | 13/100 [00:02<00:13,  6.44it/s]
# Epoch 3 batches:  14%|█▍        | 14/100 [00:02<00:13,  6.47it/s]
# Epoch 3 batches:  15%|█▌        | 15/100 [00:02<00:13,  6.44it/s]
# Epoch 3 batches:  16%|█▌        | 16/100 [00:02<00:12,  6.47it/s]
# Epoch 3 batches:  17%|█▋        | 17/100 [00:02<00:12,  6.45it/s]
# Epoch 3 batches:  18%|█▊        | 18/100 [00:02<00:13,  6.29it/s]
# Epoch 3 batches:  19%|█▉        | 19/100 [00:03<00:13,  6.16it/s]
# Epoch 3 batches:  20%|██        | 20/100 [00:03<00:12,  6.25it/s]
# Epoch 3 batches:  21%|██        | 21/100 [00:03<00:12,  6.32it/s]
# Epoch 3 batches:  22%|██▏       | 22/100 [00:03<00:13,  5.98it/s]
# Epoch 3 batches:  94%|█████████▍| 94/100 [00:15<00:00,  6.27it/s]
# Epoch 3 batches:  95%|█████████▌| 95/100 [00:15<00:00,  6.33it/s]
# Epoch 3 batches:  96%|█████████▌| 96/100 [00:15<00:00,  6.10it/s]
# Epoch 3 batches:  97%|█████████▋| 97/100 [00:15<00:00,  6.14it/s]
# Epoch 3 batches:  98%|█████████▊| 98/100 [00:15<00:00,  6.26it/s]
# Epoch 3 batches:  99%|█████████▉| 99/100 [00:15<00:00,  6.35it/s]
# Epoch 3 batches: 100%|██████████| 100/100 [00:16<00:00,  6.95it/s]
# Epoch 3 | Train Loss: 0.0030, Acc: 99.94%
# Training Epochs:  15%|█▌        | 3/20 [01:06<06:09, 21.75s/it]
# Epoch [3/20] | Train Loss: 0.0030, Acc: 99.94% | Val Loss: 0.0699, Acc: 97.79%
# Epoch 4 batches:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 4 batches:   1%|          | 1/100 [00:00<00:17,  5.52it/s]
# Epoch 4 batches:   2%|▏         | 2/100 [00:00<00:17,  5.52it/s]
# Epoch 4 batches:   3%|▎         | 3/100 [00:00<00:16,  5.83it/s]
# Epoch 4 batches:   4%|▍         | 4/100 [00:00<00:15,  6.07it/s]
# Epoch 4 batches:   5%|▌         | 5/100 [00:00<00:15,  6.26it/s]
# Epoch 4 batches:   6%|▌         | 6/100 [00:00<00:14,  6.41it/s]
# Epoch 4 batches:   7%|▋         | 7/100 [00:01<00:14,  6.38it/s]
# Epoch 4 batches:   8%|▊         | 8/100 [00:01<00:14,  6.45it/s]
# Epoch 4 batches:   9%|▉         | 9/100 [00:01<00:14,  6.43it/s]
# Epoch 4 batches:  10%|█         | 10/100 [00:01<00:14,  6.28it/s]
# Epoch 4 batches:  11%|█         | 11/100 [00:01<00:14,  6.21it/s]
# Epoch 4 batches:  12%|█▏        | 12/100 [00:01<00:13,  6.31it/s]
# Epoch 4 batches:  13%|█▎        | 13/100 [00:02<00:13,  6.38it/s]
# Epoch 4 batches:  14%|█▍        | 14/100 [00:02<00:13,  6.42it/s]
# Epoch 4 batches:  15%|█▌        | 15/100 [00:02<00:13,  6.49it/s]
# Epoch 4 batches:  16%|█▌        | 16/100 [00:02<00:12,  6.56it/s]
# Epoch 4 batches:  17%|█▋        | 17/100 [00:02<00:12,  6.49it/s]
# Epoch 4 batches:  18%|█▊        | 18/100 [00:02<00:12,  6.51it/s]
# Epoch 4 batches:  19%|█▉        | 19/100 [00:02<00:12,  6.55it/s]
# Epoch 4 batches:  20%|██        | 20/100 [00:03<00:12,  6.57it/s]
# Epoch 4 batches:  21%|██        | 21/100 [00:03<00:12,  6.41it/s]
# Epoch 4 batches:  22%|██▏       | 22/100 [00:03<00:12,  6.39it/s]
# Epoch 4 batches:  23%|██▎       | 23/100 [00:03<00:12,  6.40it/s]
# Epoch 4 batches:  24%|██▍       | 24/100 [00:03<00:11,  6.41it/s]
# Epoch 4 batches:  25%|██▌       | 25/100 [00:03<00:11,  6.43it/s]
# Epoch 4 batches:  26%|██▌       | 26/100 [00:04<00:11,  6.47it/s]
# Epoch 4 batches:  27%|██▋       | 27/100 [00:04<00:11,  6.48it/s]
# Epoch 4 batches:  99%|█████████▉| 99/100 [00:15<00:00,  6.39it/s]
# Epoch 4 batches: 100%|██████████| 100/100 [00:16<00:00,  6.94it/s]
# Epoch 4 | Train Loss: 0.0008, Acc: 100.00%
# Training Epochs:  20%|██        | 4/20 [01:26<05:37, 21.11s/it]
# Epoch [4/20] | Train Loss: 0.0008, Acc: 100.00% | Val Loss: 0.0744, Acc: 97.64%
# Epoch 5 batches:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 5 batches:   1%|          | 1/100 [00:00<00:16,  6.08it/s]
# Epoch 5 batches:   2%|▏         | 2/100 [00:00<00:16,  5.92it/s]
# Epoch 5 batches:   3%|▎         | 3/100 [00:00<00:16,  5.84it/s]
# Epoch 5 batches:   4%|▍         | 4/100 [00:00<00:15,  6.03it/s]
# Epoch 5 batches:   5%|▌         | 5/100 [00:00<00:15,  6.12it/s]
# Epoch 5 batches:   6%|▌         | 6/100 [00:00<00:15,  6.09it/s]
# Epoch 5 batches:   7%|▋         | 7/100 [00:01<00:14,  6.23it/s]
# Epoch 5 batches:   8%|▊         | 8/100 [00:01<00:14,  6.34it/s]
# Epoch 5 batches:   9%|▉         | 9/100 [00:01<00:14,  6.35it/s]
# Epoch 5 batches:  10%|█         | 10/100 [00:01<00:14,  6.07it/s]
# Epoch 5 batches:  11%|█         | 11/100 [00:01<00:14,  5.94it/s]
# Epoch 5 batches:  12%|█▏        | 12/100 [00:01<00:14,  5.88it/s]
# Epoch 5 batches:  13%|█▎        | 13/100 [00:02<00:15,  5.77it/s]
# Epoch 5 batches:  14%|█▍        | 14/100 [00:02<00:14,  5.76it/s]
# Epoch 5 batches:  15%|█▌        | 15/100 [00:02<00:15,  5.66it/s]
# Epoch 5 batches:  16%|█▌        | 16/100 [00:02<00:15,  5.58it/s]
# Epoch 5 batches:  17%|█▋        | 17/100 [00:02<00:14,  5.57it/s]
# Epoch 5 batches:  18%|█▊        | 18/100 [00:03<00:14,  5.54it/s]
# Epoch 5 batches:  19%|█▉        | 19/100 [00:03<00:14,  5.56it/s]
# Epoch 5 batches:  20%|██        | 20/100 [00:03<00:15,  5.24it/s]
# Epoch 5 batches:  21%|██        | 21/100 [00:04<00:25,  3.13it/s]
# Epoch 5 batches:  22%|██▏       | 22/100 [00:04<00:23,  3.31it/s]
# Epoch 5 batches:  23%|██▎       | 23/100 [00:04<00:20,  3.72it/s]
# Epoch 5 batches:  24%|██▍       | 24/100 [00:04<00:18,  4.11it/s]
# Epoch 5 batches:  25%|██▌       | 25/100 [00:04<00:16,  4.59it/s]
# Epoch 5 batches:  26%|██▌       | 26/100 [00:05<00:14,  5.04it/s]
# Epoch 5 batches:  27%|██▋       | 27/100 [00:05<00:13,  5.43it/s]
# Epoch 5 batches:  28%|██▊       | 28/100 [00:05<00:12,  5.73it/s]
# Epoch 5 batches:  29%|██▉       | 29/100 [00:05<00:11,  5.93it/s]
# Epoch 5 batches:  30%|███       | 30/100 [00:05<00:11,  6.00it/s]
# Epoch 5 batches:  31%|███       | 31/100 [00:05<00:11,  6.18it/s]
# Epoch 5 batches:  68%|██████▊   | 68/100 [00:11<00:05,  6.29it/s]
# Epoch 5 batches:  69%|██████▉   | 69/100 [00:11<00:04,  6.34it/s]
# Epoch 5 batches:  70%|███████   | 70/100 [00:11<00:04,  6.42it/s]
# Epoch 5 batches:  71%|███████   | 71/100 [00:12<00:04,  6.46it/s]
# Epoch 5 batches:  72%|███████▏  | 72/100 [00:12<00:04,  6.50it/s]
# Epoch 5 batches:  73%|███████▎  | 73/100 [00:12<00:04,  6.54it/s]
# Epoch 5 batches:  74%|███████▍  | 74/100 [00:12<00:03,  6.55it/s]
# Epoch 5 batches:  75%|███████▌  | 75/100 [00:12<00:03,  6.56it/s]
# Epoch 5 batches:  76%|███████▌  | 76/100 [00:13<00:05,  4.76it/s]
# Epoch 5 batches:  77%|███████▋  | 77/100 [00:13<00:05,  4.17it/s]
# Epoch 5 batches:  78%|███████▊  | 78/100 [00:13<00:04,  4.60it/s]
# Epoch 5 batches:  79%|███████▉  | 79/100 [00:13<00:04,  5.01it/s]
# Epoch 5 batches:  80%|████████  | 80/100 [00:13<00:03,  5.33it/s]
# Epoch 5 batches:  81%|████████  | 81/100 [00:14<00:04,  4.12it/s]
# Epoch 5 batches:  82%|████████▏ | 82/100 [00:14<00:04,  4.30it/s]
# Epoch 5 batches:  83%|████████▎ | 83/100 [00:14<00:03,  4.76it/s]
# Epoch 5 batches:  84%|████████▍ | 84/100 [00:14<00:03,  5.19it/s]
# Epoch 5 batches:  85%|████████▌ | 85/100 [00:14<00:02,  5.33it/s]
# Epoch 5 batches:  86%|████████▌ | 86/100 [00:15<00:02,  5.31it/s]
# Epoch 5 batches:  87%|████████▋ | 87/100 [00:15<00:02,  5.34it/s]
# Epoch 5 batches:  88%|████████▊ | 88/100 [00:15<00:02,  5.41it/s]
# Epoch 5 batches:  89%|████████▉ | 89/100 [00:15<00:02,  5.44it/s]
# Epoch 5 batches:  90%|█████████ | 90/100 [00:15<00:01,  5.51it/s]
# Epoch 5 batches:  91%|█████████ | 91/100 [00:15<00:01,  5.37it/s]
# Epoch 5 batches:  92%|█████████▏| 92/100 [00:16<00:01,  5.30it/s]
# Epoch 5 batches:  93%|█████████▎| 93/100 [00:16<00:01,  5.36it/s]
# Epoch 5 batches:  94%|█████████▍| 94/100 [00:16<00:01,  5.42it/s]
# Epoch 5 batches:  95%|█████████▌| 95/100 [00:16<00:00,  5.47it/s]
# Epoch 5 batches:  96%|█████████▌| 96/100 [00:16<00:00,  5.46it/s]
# Epoch 5 batches:  97%|█████████▋| 97/100 [00:17<00:00,  5.30it/s]
# Epoch 5 batches:  98%|█████████▊| 98/100 [00:17<00:00,  5.28it/s]
# Epoch 5 batches:  99%|█████████▉| 99/100 [00:17<00:00,  5.32it/s]
# Epoch 5 batches: 100%|██████████| 100/100 [00:17<00:00,  5.77it/s]
# Epoch 5 | Train Loss: 0.0015, Acc: 100.00%
# Training Epochs:  25%|██▌       | 5/20 [01:48<05:20, 21.35s/it]
# Epoch [5/20] | Train Loss: 0.0015, Acc: 100.00% | Val Loss: 0.1243, Acc: 96.64%
# Epoch 6 batches:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 6 batches:   1%|          | 1/100 [00:00<00:16,  5.97it/s]
# Epoch 6 batches:   2%|▏         | 2/100 [00:00<00:16,  5.99it/s]
# Epoch 6 batches:   3%|▎         | 3/100 [00:00<00:15,  6.08it/s]
# Epoch 6 batches:   4%|▍         | 4/100 [00:00<00:15,  6.03it/s]
# Epoch 6 batches:   5%|▌         | 5/100 [00:00<00:15,  6.22it/s]
# Epoch 6 batches:   6%|▌         | 6/100 [00:00<00:14,  6.33it/s]
# Epoch 6 batches:   7%|▋         | 7/100 [00:01<00:14,  6.41it/s]
# Epoch 6 batches:   8%|▊         | 8/100 [00:01<00:14,  6.47it/s]
# Epoch 6 batches:   9%|▉         | 9/100 [00:01<00:13,  6.51it/s]
# Epoch 6 batches:  10%|█         | 10/100 [00:01<00:13,  6.43it/s]
# Epoch 6 batches:  11%|█         | 11/100 [00:01<00:13,  6.38it/s]
# Epoch 6 batches:  12%|█▏        | 12/100 [00:01<00:13,  6.46it/s]
# Epoch 6 batches:  13%|█▎        | 13/100 [00:02<00:13,  6.51it/s]
# Epoch 6 batches:  14%|█▍        | 14/100 [00:02<00:13,  6.55it/s]
# Epoch 6 batches:  15%|█▌        | 15/100 [00:02<00:13,  6.54it/s]
# Epoch 6 batches:  16%|█▌        | 16/100 [00:02<00:12,  6.53it/s]
# Epoch 6 batches:  17%|█▋        | 17/100 [00:02<00:13,  6.36it/s]
# Epoch 6 batches:  18%|█▊        | 18/100 [00:02<00:12,  6.42it/s]
# Epoch 6 batches:  19%|█▉        | 19/100 [00:02<00:12,  6.33it/s]
# Epoch 6 batches:  20%|██        | 20/100 [00:03<00:12,  6.30it/s]
# Epoch 6 batches:  21%|██        | 21/100 [00:03<00:12,  6.33it/s]
# Epoch 6 batches:  22%|██▏       | 22/100 [00:03<00:12,  6.40it/s]
# Epoch 6 batches:  23%|██▎       | 23/100 [00:03<00:12,  6.28it/s]
# Epoch 6 batches:  24%|██▍       | 24/100 [00:03<00:12,  6.17it/s]
# Epoch 6 batches:  25%|██▌       | 25/100 [00:03<00:12,  6.20it/s]
# Epoch 6 batches:  26%|██▌       | 26/100 [00:04<00:11,  6.28it/s]
# Epoch 6 batches:  27%|██▋       | 27/100 [00:04<00:11,  6.36it/s]
# Epoch 6 batches:  28%|██▊       | 28/100 [00:04<00:11,  6.42it/s]
# Epoch 6 batches:  29%|██▉       | 29/100 [00:04<00:11,  6.30it/s]
# Epoch 6 batches:  30%|███       | 30/100 [00:04<00:11,  6.25it/s]
# Epoch 6 batches:  31%|███       | 31/100 [00:04<00:10,  6.34it/s]
# Epoch 6 batches:  32%|███▏      | 32/100 [00:05<00:10,  6.41it/s]
# Epoch 6 batches:  33%|███▎      | 33/100 [00:05<00:10,  6.32it/s]
# Epoch 6 batches:  34%|███▍      | 34/100 [00:05<00:10,  6.34it/s]
# Epoch 6 batches:  35%|███▌      | 35/100 [00:05<00:10,  6.39it/s]
# Epoch 6 batches:  36%|███▌      | 36/100 [00:05<00:10,  6.31it/s]
# Epoch 6 batches:  72%|███████▏  | 72/100 [00:12<00:04,  6.48it/s]
# Epoch 6 batches:  73%|███████▎  | 73/100 [00:12<00:04,  6.34it/s]
# Epoch 6 batches:  74%|███████▍  | 74/100 [00:12<00:04,  6.39it/s]
# Epoch 6 batches:  75%|███████▌  | 75/100 [00:12<00:03,  6.44it/s]
# Epoch 6 batches:  76%|███████▌  | 76/100 [00:12<00:03,  6.39it/s]
# Epoch 6 batches:  77%|███████▋  | 77/100 [00:12<00:03,  6.43it/s]
# Epoch 6 batches:  78%|███████▊  | 78/100 [00:12<00:03,  6.43it/s]
# Epoch 6 batches:  79%|███████▉  | 79/100 [00:13<00:03,  6.33it/s]
# Epoch 6 batches:  80%|████████  | 80/100 [00:13<00:03,  6.19it/s]
# Epoch 6 batches:  81%|████████  | 81/100 [00:13<00:03,  6.22it/s]
# Epoch 6 batches:  82%|████████▏ | 82/100 [00:13<00:02,  6.30it/s]
# Epoch 6 batches:  83%|████████▎ | 83/100 [00:13<00:02,  6.34it/s]
# Epoch 6 batches:  84%|████████▍ | 84/100 [00:13<00:02,  6.40it/s]
# Epoch 6 batches:  85%|████████▌ | 85/100 [00:14<00:02,  6.47it/s]
# Epoch 6 batches:  86%|████████▌ | 86/100 [00:14<00:02,  6.50it/s]
# Epoch 6 batches:  87%|████████▋ | 87/100 [00:14<00:02,  6.31it/s]
# Epoch 6 batches:  88%|████████▊ | 88/100 [00:14<00:01,  6.37it/s]
# Epoch 6 batches:  89%|████████▉ | 89/100 [00:14<00:01,  6.40it/s]
# Epoch 6 batches:  90%|█████████ | 90/100 [00:14<00:01,  6.41it/s]
# Epoch 6 batches:  91%|█████████ | 91/100 [00:14<00:01,  6.45it/s]
# Epoch 6 batches:  92%|█████████▏| 92/100 [00:15<00:01,  6.26it/s]
# Epoch 6 batches:  93%|█████████▎| 93/100 [00:15<00:01,  6.30it/s]
# Epoch 6 batches:  94%|█████████▍| 94/100 [00:15<00:00,  6.33it/s]
# Epoch 6 batches:  95%|█████████▌| 95/100 [00:15<00:00,  6.23it/s]
# Epoch 6 batches:  96%|█████████▌| 96/100 [00:15<00:00,  6.15it/s]
# Epoch 6 batches:  97%|█████████▋| 97/100 [00:15<00:00,  6.28it/s]
# Epoch 6 batches:  98%|█████████▊| 98/100 [00:16<00:00,  6.32it/s]
# Epoch 6 batches:  99%|█████████▉| 99/100 [00:16<00:00,  6.32it/s]
# Epoch 6 batches: 100%|██████████| 100/100 [00:16<00:00,  6.90it/s]
# Epoch 6 | Train Loss: 0.0006, Acc: 100.00%
# Training Epochs:  25%|██▌       | 5/20 [02:09<06:28, 25.87s/it]
# Epoch [6/20] | Train Loss: 0.0006, Acc: 100.00% | Val Loss: 0.1004, Acc: 97.33%
# Early stopping at epoch 6
# ✅ Best model saved to resnet18_binary_tumor.pth
# Classification Report:
#               precision    recall  f1-score   support
#
#      notumor       0.93      1.00      0.97       405
#        tumor       1.00      0.97      0.98       906
#
#     accuracy                           0.98      1311
#    macro avg       0.97      0.98      0.97      1311
# weighted avg       0.98      0.98      0.98      1311
